# %%
import  sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

# %%
dataset=pd.read_csv('Dataset.csv')
data=dataset.iloc[:,1:]

# %%
dataset.head()
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc

# %%
le = preprocessing.LabelEncoder()

# %%
buying = le.fit_transform(list(dataset["buying"]))
maint = le.fit_transform(list(dataset["maint"]))
door = le.fit_transform(list(dataset["door"]))
persons = le.fit_transform(list(dataset["persons"]))
lug_boot = le.fit_transform(list(dataset["lug_boot"]))
safety = le.fit_transform(list(dataset["safety"]))
cls = le.fit_transform(list(dataset["class"]))
print(buying)
# Out:
# [3 3 3 ... 1 1 1]

# %%
predict = "class"

# %%
x = list(zip(buying, maint, door, persons, lug_boot, safety)) # features
y = list(cls) # labels

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size = 0.1)

# %%
neighbors = 9
model = KNeighborsClassifier(n_neighbors=neighbors)
# Train the model
model.fit(x_train, y_train)
# Get the accuracy
acc = model.score(x_test, y_test)

# %%
predicted = model.predict(x_test)
names = ["unacc", "acc", "good", "vgood"]

for x in range(len(predicted)):
    print("Predicted: ", names[predicted[x]], "Data: ", x_test[x], "Actual: ", names[y_test[x]])
    n = model.kneighbors([x_test[x]], neighbors, True)
    print("N: ", n)
    print()
    print()

print("Accuracy: ", acc)
# Out:
# Predicted:  unacc Data:  (2, 0, 3, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1420,  255,  983, 1508,   46,  100, 1537,  205,   78]]))
#
#
# Predicted:  unacc Data:  (3, 2, 2, 2, 1, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 332, 1196, 1501, 1514,  420,  448, 1082,  860,   42]]))
#
#
# Predicted:  good Data:  (2, 2, 0, 2, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 806,  101,  985, 1472,  949,  381,  697,  906,  796]]))
#
#
# Predicted:  good Data:  (3, 3, 0, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1258,  415,  894,  658,  278,   85, 1271,  390,  601]]))
#
#
# Predicted:  good Data:  (1, 0, 3, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1452,   78,  205, 1312,  984,  208, 1174,  889,  631]]))
#
#
# Predicted:  good Data:  (2, 1, 2, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  20,  789,  855, 1065,  436,   70,   21,  758, 1250]]))
#
#
# Predicted:  good Data:  (2, 0, 1, 1, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 310, 1540, 1022, 1521,  708,  752,  686,  932,  404]]))
#
#
# Predicted:  good Data:  (3, 3, 3, 0, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 742, 1184, 1059, 1252, 1165, 1093,  569,  934, 1031]]))
#
#
# Predicted:  good Data:  (0, 1, 2, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1142, 1143, 1246,  368, 1309,  531, 1351, 1467, 1109]]))
#
#
# Predicted:  good Data:  (2, 0, 1, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 919, 1222,  460,  391,  988, 1390,  944,  331, 1034]]))
#
#
# Predicted:  unacc Data:  (0, 0, 2, 2, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 369,  400, 1261,  809,  570,  235, 1087,  157,  553]]))
#
#
# Predicted:  unacc Data:  (2, 3, 2, 2, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 256, 1226,  537,  965, 1159, 1064,  423, 1330,  386]]))
#
#
# Predicted:  good Data:  (2, 3, 0, 1, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1344,  894,  605, 1504,  223, 1085, 1139,  389,  601]]))
#
#
# Predicted:  good Data:  (2, 1, 1, 0, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1390,  224, 1323, 1144, 1100,  528,  917,  339,  758]]))
#
#
# Predicted:  good Data:  (3, 3, 1, 2, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 103, 1166, 1002,  839,  632, 1493, 1547,  163,  180]]))
#
#
# Predicted:  good Data:  (0, 2, 0, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 536,  429,  630,  312,  770, 1377,  773,  295,   36]]))
#
#
# Predicted:  good Data:  (0, 1, 2, 0, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1246, 1274, 1383,  326, 1307,  524,   52,  947, 1364]]))
#
#
# Predicted:  good Data:  (3, 1, 3, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[718, 150, 168, 354, 352, 941, 916,  70, 221]]))
#
#
# Predicted:  unacc Data:  (2, 0, 1, 1, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 460, 1455, 1264,  593, 1390, 1412, 1224,  577,  246]]))
#
#
# Predicted:  good Data:  (0, 0, 1, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1331, 1134,  240,  931,  685,  823,   26,  473,  265]]))
#
#
# Predicted:  good Data:  (0, 3, 0, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 630,  452, 1084, 1377,  477, 1188, 1349, 1099, 1494]]))
#
#
# Predicted:  good Data:  (0, 0, 3, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1174,  280,  889,  631, 1418, 1036,  370,  364, 1274]]))
#
#
# Predicted:  good Data:  (2, 1, 2, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 892,  348, 1100, 1228,  391,  635,  674, 1435,  494]]))
#
#
# Predicted:  good Data:  (0, 0, 1, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 235, 1143, 1351,  581, 1134,  836,  768,  261,  220]]))
#
#
# Predicted:  good Data:  (2, 3, 3, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 600,  344,  537,  588,  545, 1117,  309, 1159,  735]]))
#
#
# Predicted:  good Data:  (1, 3, 0, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1504, 1101,  956, 1251,  452, 1341, 1084, 1032,  997]]))
#
#
# Predicted:  unacc Data:  (0, 0, 3, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 400, 1174,  328,  285,  889,  570,  149, 1029, 1116]]))
#
#
# Predicted:  good Data:  (3, 0, 1, 2, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 388,  158, 1374, 1433, 1050, 1522, 1417,  803,  125]]))
#
#
# Predicted:  good Data:  (3, 0, 2, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1114,  374,  657,  649, 1051,  563,  356,    2,  172]]))
#
#
# Predicted:  good Data:  (3, 3, 0, 1, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 472, 1370, 1239,  590, 1547, 1353, 1457,  488, 1531]]))
#
#
# Predicted:  good Data:  (3, 3, 1, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 871, 1039,  590,  257, 1371, 1547,  922,  435,  975]]))
#
#
# Predicted:  vgood Data:  (1, 1, 3, 1, 0, 0) Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 887,  933, 1454, 1091, 1289,  863,   13, 1014,  547]]))
#
#
# Predicted:  good Data:  (3, 1, 2, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 820,  747, 1524,  470,  300, 1163, 1325,   70,   21]]))
#
#
# Predicted:  good Data:  (0, 2, 0, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 189,  450,  315,  637, 1415,  903,  504,  793,  687]]))
#
#
# Predicted:  good Data:  (0, 3, 0, 1, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 161,  188,  613,  383,  468, 1013, 1470,  630,  477]]))
#
#
# Predicted:  good Data:  (0, 2, 2, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 637,  729, 1027,  432,   25, 1438,  228,  629,  361]]))
#
#
# Predicted:  good Data:  (0, 2, 3, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 646,  232,  625,  245, 1536,  182,  631, 1023, 1307]]))
#
#
# Predicted:  good Data:  (2, 2, 0, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 533, 1321,  601, 1271, 1090,  680,  406,  677, 1434]]))
#
#
# Predicted:  good Data:  (1, 1, 0, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1229,   87,  327,  876, 1128,  781,  320,  728,  302]]))
#
#
# Predicted:  good Data:  (3, 1, 0, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[777, 692, 337, 697, 381, 621, 907, 294, 387]]))
#
#
# Predicted:  good Data:  (1, 3, 0, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[  77, 1017,  719,    7,  424,  455,  731, 1552,  981]]))
#
#
# Predicted:  good Data:  (2, 0, 3, 0, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[  56,  596, 1175,  785,  104,  216,  425,  218,  229]]))
#
#
# Predicted:  unacc Data:  (1, 0, 3, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1537, 1018,  984,  799,  205,  328,  285, 1174,  400]]))
#
#
# Predicted:  good Data:  (1, 2, 1, 0, 2, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1318, 1219,  406,  372, 1429,  143,  239,  258,  533]]))
#
#
# Predicted:  unacc Data:  (1, 2, 3, 1, 2, 0) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 810,   49,   69,  998,  317, 1262,  645, 1542,  285]]))
#
#
# Predicted:  good Data:  (1, 3, 0, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 289,    7,  316,  903,  373,  315,  619, 1552, 1259]]))
#
#
# Predicted:  good Data:  (0, 0, 2, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 122,  852,  990, 1358,  254, 1109, 1418,  280,  497]]))
#
#
# Predicted:  acc Data:  (1, 1, 3, 2, 0, 2) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 271,  737,  732,  412,  960,  396, 1384,  518,  218]]))
#
#
# Predicted:  good Data:  (0, 0, 0, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 931, 1232,    4, 1551,  823,  206, 1260,  243,  145]]))
#
#
# Predicted:  good Data:  (1, 0, 3, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1098,  280, 1346,  880,  203, 1192,  852, 1286, 1255]]))
#
#
# Predicted:  good Data:  (1, 0, 1, 0, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[  71,  417, 1010,  229,  973,  995, 1546,  240,  736]]))
#
#
# Predicted:  unacc Data:  (3, 2, 3, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1253, 1391,  939,  945, 1047,  236,  317,  980,  716]]))
#
#
# Predicted:  good Data:  (2, 0, 0, 2, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1061,  196, 1138,  633, 1067, 1281,  120,   62, 1386]]))
#
#
# Predicted:  good Data:  (0, 2, 2, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 111,  324,  516, 1287,  898,   88,  951,  968, 1393]]))
#
#
# Predicted:  good Data:  (1, 3, 1, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1043,  289,   33,  386, 1428,  200,  731,  608,  981]]))
#
#
# Predicted:  good Data:  (0, 1, 3, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 909, 1073, 1177, 1302,  602,  744, 1042,  328,   10]]))
#
#
# Predicted:  good Data:  (2, 1, 1, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1133,  375,   82,  989,  494,  339,  758,  224,  426]]))
#
#
# Predicted:  good Data:  (3, 3, 0, 0, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1139, 1457,   90, 1239,  576,  443, 1315,   63, 1531]]))
#
#
# Predicted:  good Data:  (0, 3, 2, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1337,  893, 1541,  147, 1028, 1393, 1382, 1519, 1464]]))
#
#
# Predicted:  unacc Data:  (2, 0, 2, 2, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 983,  291,  156, 1389,  809,  999, 1018,  752,  586]]))
#
#
# Predicted:  unacc Data:  (1, 2, 0, 1, 1, 0) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[867, 429, 890, 689, 877, 137, 295,  29, 719]]))
#
#
# Predicted:  good Data:  (1, 0, 2, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1331,  705, 1025,  492,  556, 1202,   26, 1298,  888]]))
#
#
# Predicted:  good Data:  (3, 3, 1, 2, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 256,  403, 1279,  259, 1548,  615,  332,  290,  414]]))
#
#
# Predicted:  unacc Data:  (3, 2, 1, 1, 2, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 281,  945,   94,  615,  253,   38, 1548,  740,  861]]))
#
#
# Predicted:  good Data:  (2, 0, 0, 2, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1095, 1157, 1067,  952,  120,   64,  819,  777, 1241]]))
#
#
# Predicted:  good Data:  (3, 0, 0, 1, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1070,  347, 1186,  986,   41,  741, 1110,  479,  279]]))
#
#
# Predicted:  good Data:  (1, 2, 1, 2, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  27,  313, 1223,  831, 1112,  762,  123,  496,  395]]))
#
#
# Predicted:  good Data:  (1, 1, 1, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1158,  797,    3,  617,  670,  928, 1399,  124,  788]]))
#
#
# Predicted:  good Data:  (1, 2, 0, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 350,   79,  395, 1120,  856,  496,   97,  126,   29]]))
#
#
# Predicted:  unacc Data:  (1, 0, 3, 2, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1119, 1149, 1317, 1268,  218,  554,  745,  342,  805]]))
#
#
# Predicted:  good Data:  (2, 1, 1, 2, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 599,  493, 1015,  831,  684,  153, 1004,  421,  885]]))
#
#
# Predicted:  good Data:  (0, 1, 3, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 970,  325,  737, 1054,  663,  396,  904,  102,  233]]))
#
#
# Predicted:  good Data:  (0, 1, 3, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1234,  664,    9, 1362,  519,  292,  520, 1029,  342]]))
#
#
# Predicted:  unacc Data:  (0, 1, 0, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 269, 1115,  393, 1162, 1151,  248, 1372,  319, 1463]]))
#
#
# Predicted:  unacc Data:  (2, 3, 2, 1, 0, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1328, 1079,  565, 1380,   89,  606, 1535,  534,  825]]))
#
#
# Predicted:  unacc Data:  (1, 0, 1, 1, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 940,  924, 1440,  779,  788, 1347,  736,  113,  318]]))
#
#
# Predicted:  good Data:  (0, 3, 3, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 641,  634, 1296, 1475,  707, 1293, 1554,  185,  893]]))
#
#
# Predicted:  good Data:  (0, 0, 1, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 299,  318,  594, 1490,  670, 1208, 1532,  788,  959]]))
#
#
# Predicted:  good Data:  (0, 3, 3, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 309,  761,  627, 1189,  561,  195, 1062, 1248,  228]]))
#
#
# Predicted:  vgood Data:  (1, 1, 0, 1, 0, 0) Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1120,  816,  786,   29,  393,  252,  476,  877,  269]]))
#
#
# Predicted:  unacc Data:  (1, 0, 3, 1, 2, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1488, 1073, 1025,  905, 1177,  955,  799, 1298,   10]]))
#
#
# Predicted:  unacc Data:  (2, 3, 3, 1, 1, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 716, 1396, 1079, 1442, 1020,  213, 1528,  329,   89]]))
#
#
# Predicted:  good Data:  (3, 1, 2, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 720, 1342,  748, 1049,  837, 1533,  854,  183, 1249]]))
#
#
# Predicted:  unacc Data:  (2, 2, 0, 1, 1, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 389,   40,  601,  929, 1269,  680, 1437,  899,  467]]))
#
#
# Predicted:  good Data:  (2, 3, 0, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 950,  780, 1430, 1084, 1531, 1414,  605, 1297, 1090]]))
#
#
# Predicted:  good Data:  (2, 3, 1, 2, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 210,  624,  200,  851, 1428,  808, 1279, 1548,  403]]))
#
#
# Predicted:  unacc Data:  (1, 0, 0, 2, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 743, 1357,  940,  788, 1280,  201,  715,  299,  982]]))
#
#
# Predicted:  good Data:  (2, 2, 3, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 236,  775,  214,  164, 1262,  562, 1164,  317,  724]]))
#
#
# Predicted:  unacc Data:  (2, 0, 2, 2, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1069, 1268, 1433,  288,  554, 1329, 1417, 1118,  788]]))
#
#
# Predicted:  good Data:  (2, 0, 2, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 282,  752, 1113, 1076,  901, 1018,  100, 1222,  703]]))
#
#
# Predicted:  good Data:  (0, 3, 2, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 495,  893, 1541,  490, 1009,  207, 1554,  972,   52]]))
#
#
# Predicted:  good Data:  (3, 1, 1, 0, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 294,  927, 1397,   92,  749, 1513,  574,  401,  482]]))
#
#
# Predicted:  good Data:  (1, 2, 2, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 436,  898,  416,  968,  159,  530,  502, 1033,  640]]))
#
#
# Predicted:  unacc Data:  (1, 1, 0, 1, 1, 2) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1128, 1437,  676, 1511,  456,  327,  262,   73,  713]]))
#
#
# Predicted:  good Data:  (2, 2, 0, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1197,  876,   40, 1235, 1297, 1090,  680,   87,  118]]))
#
#
# Predicted:  unacc Data:  (1, 0, 1, 2, 1, 0) Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 875,  560, 1135, 1530,  883, 1087,  340,  586,  772]]))
#
#
# Predicted:  good Data:  (3, 1, 2, 0, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 941,  183, 1152, 1367,  140,  837,  987,  150,   70]]))
#
#
# Predicted:  good Data:  (1, 1, 0, 1, 2, 0) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 877,   74,  908,  508,  238,  283, 1003,  801,  166]]))
#
#
# Predicted:  good Data:  (3, 2, 0, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 601, 1271,  910,  899,  691,  152,  390,  859,  986]]))
#
#
# Predicted:  good Data:  (1, 3, 0, 0, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 468,  709,  130, 1194, 1453, 1314,  613,   97, 1349]]))
#
#
# Predicted:  good Data:  (2, 1, 0, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 381,  621, 1243, 1130,  906, 1030,  467,  774,  152]]))
#
#
# Predicted:  good Data:  (2, 0, 2, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 686,  465, 1225, 1292,  999,  282,  483, 1517,  835]]))
#
#
# Predicted:  good Data:  (1, 3, 0, 1, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1084,  477,  981,  605, 1504,  890,   97, 1552, 1314]]))
#
#
# Predicted:  good Data:  (2, 3, 2, 0, 1, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1337,  868,  550, 1550,  146,  509,  787,  522,  655]]))
#
#
# Predicted:  good Data:  (1, 3, 0, 2, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 200,   54,  688,  624,  604,   77,  890, 1552,  453]]))
#
#
# Predicted:  good Data:  (0, 2, 1, 1, 2, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[258, 432, 754, 265, 564, 637, 372, 189, 377]]))
#
#
# Predicted:  good Data:  (1, 3, 1, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1169,  416,  981,  950, 1084,  696, 1033,  956, 1099]]))
#
#
# Predicted:  good Data:  (3, 1, 1, 1, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 388, 1249, 1198,  837, 1522,  987,  506,  297,   61]]))
#
#
# Predicted:  good Data:  (2, 3, 0, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 373,  841,  316, 1387,  601,  894,  796,  278, 1414]]))
#
#
# Predicted:  good Data:  (3, 0, 2, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1089, 1220,  944,  961,  348,  391, 1276,  339, 1034]]))
#
#
# Predicted:  good Data:  (0, 3, 1, 0, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1188,  186, 1147,  439, 1436, 1169, 1099,  643, 1494]]))
#
#
# Predicted:  unacc Data:  (2, 2, 1, 2, 0, 2) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  17,  762,  831,  921, 1166,   50,  632,  695,  153]]))
#
#
# Predicted:  good Data:  (0, 2, 0, 0, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 579,  702,  144,  997, 1326, 1172,  897,  350,  126]]))
#
#
# Predicted:  good Data:  (3, 2, 1, 0, 1, 0) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 339, 1385,  362,   94,   82,  281, 1213,  250, 1263]]))
#
#
# Predicted:  vgood Data:  (1, 0, 2, 1, 1, 0) Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  15,  409,  560, 1141, 1018,  984,  772,  370, 1452]]))
#
#
# Predicted:  good Data:  (0, 3, 1, 0, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 671,  188,  207,  495, 1494,  613, 1453,  630, 1349]]))
#
#
# Predicted:  unacc Data:  (3, 2, 3, 2, 1, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[  16,  911,  170,  380, 1421,  116,  734,  804, 1145]]))
#
#
# Predicted:  vgood Data:  (2, 1, 1, 1, 0, 0) Actual:  vgood
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 989,  421, 1553,  141,  684,  816,  753,  786,  323]]))
#
#
# Predicted:  good Data:  (2, 0, 1, 0, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1390,  425,  577,  973,  498,   71,  917,  833,  988]]))
#
#
# Predicted:  good Data:  (2, 0, 0, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 438, 1222,  919,  828,   47,  946,   64, 1034,  932]]))
#
#
# Predicted:  good Data:  (3, 2, 3, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 334,   96, 1057, 1063, 1031, 1350,  979,  865,  941]]))
#
#
# Predicted:  unacc Data:  (0, 1, 2, 2, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1193,  134,  151,  178,  531,  553,  400,  369, 1080]]))
#
#
# Predicted:  good Data:  (0, 1, 2, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 783, 1261, 1234,  729,  237,  520, 1080,   25,   30]]))
#
#
# Predicted:  unacc Data:  (0, 2, 0, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[336, 644, 161, 399, 598, 383, 295,  29, 867]]))
#
#
# Predicted:  good Data:  (2, 1, 3, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 698,   81,  854, 1049,  636,  451,  933,   86,  547]]))
#
#
# Predicted:  good Data:  (1, 2, 0, 1, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[568, 382, 719, 327,  40,  36, 876,  29, 687]]))
#
#
# Predicted:  good Data:  (1, 1, 0, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 595, 1124,  252,  350,  710,  459, 1120,  728,  320]]))
#
#
# Predicted:  good Data:  (3, 1, 1, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 758,  482, 1398,   70, 1213,  639,  339, 1379,   87]]))
#
#
# Predicted:  unacc Data:  (0, 2, 2, 1, 0, 2) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 108, 1479,  591, 1461,   88,  111, 1055, 1075,  419]]))
#
#
# Predicted:  unacc Data:  (0, 0, 2, 2, 1, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1193, 1116,  370,  560, 1087,  181, 1155,  220,  400]]))
#
#
# Predicted:  unacc Data:  (2, 0, 1, 2, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 586,  686, 1530, 1170, 1241,  752, 1443,  120,  167]]))
#
#
# Predicted:  good Data:  (1, 1, 1, 0, 1, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 850,  938, 1128, 1546, 1010,  302, 1511,  143, 1318]]))
#
#
# Predicted:  good Data:  (3, 1, 1, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1243,  172,    2, 1322,  638,  621,    5,  337,  152]]))
#
#
# Predicted:  good Data:  (0, 1, 3, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 829,  520,   25, 1027, 1362,  849, 1042,  744,  342]]))
#
#
# Predicted:  good Data:  (2, 1, 0, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 917,   87, 1200, 1197,  498,  528,  505,  234,   61]]))
#
#
# Predicted:  good Data:  (0, 0, 2, 0, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 525,  717,  122,  229,  995, 1185,  990,  736,  364]]))
#
#
# Predicted:  unacc Data:  (0, 2, 1, 1, 2, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 267, 1060,  209,  261,  384,  873, 1516,  607,  377]]))
#
#
# Predicted:  good Data:  (2, 3, 2, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 943, 1413, 1129,  537,  600, 1285,  869, 1247,  360]]))
#
#
# Predicted:  good Data:  (3, 1, 0, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 270,  488, 1037, 1209, 1249,  387, 1198,  505,  234]]))
#
#
# Predicted:  good Data:  (0, 1, 2, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[  26,  324, 1142, 1287,  556, 1042,  685, 1302,  265]]))
#
#
# Predicted:  good Data:  (1, 3, 1, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 618, 1218,  204, 1381, 1494, 1453, 1314,  963, 1099]]))
#
#
# Predicted:  good Data:  (1, 3, 0, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 101,  949, 1552,  619, 1017, 1043,  731,  289,  200]]))
#
#
# Predicted:  good Data:  (3, 1, 3, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 175,  900, 1402, 1221,  284,  802, 1145,  558,  541]]))
#
#
# Predicted:  unacc Data:  (3, 2, 1, 1, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1352,  827, 1002,   95, 1166,  975,  474,   50, 1198]]))
#
#
# Predicted:  good Data:  (1, 3, 1, 1, 1, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 765, 1344, 1504,  853,  981, 1324,  711,  956, 1464]]))
#
#
# Predicted:  unacc Data:  (3, 2, 3, 1, 1, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1466,  980,  448,   42, 1442,  716,  583, 1273,  820]]))
#
#
# Predicted:  good Data:  (2, 1, 2, 0, 1, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 150,  787, 1068,  795,  916,  938, 1507,  171, 1152]]))
#
#
# Predicted:  good Data:  (0, 3, 2, 2, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 501, 1484, 1045, 1108,  176, 1005, 1191, 1048,  399]]))
#
#
# Predicted:  good Data:  (3, 2, 1, 2, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1340,  402,  807,  257,  332,  738, 1039,  341,   23]]))
#
#
# Predicted:  unacc Data:  (2, 1, 0, 2, 0, 2) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 885,    0, 1489,  201,  695,  467,  153, 1280,  226]]))
#
#
# Predicted:  good Data:  (3, 3, 2, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1117, 1247,  256,  169,  274, 1242, 1279,  537, 1086]]))
#
#
# Predicted:  acc Data:  (1, 1, 3, 1, 2, 0) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1216,  285, 1542,  683,   13,   46,  874, 1467,   69]]))
#
#
# Predicted:  unacc Data:  (1, 3, 3, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 329,  487, 1153,  666, 1396,   34,  667,  645, 1336]]))
#
#
# Predicted:  good Data:  (3, 1, 1, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 387, 1340,  847,  896,  506,  294, 1378,  341, 1249]]))
#
#
# Predicted:  good Data:  (3, 1, 0, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 270,  341,  507,   23,   62,  387,   65,  633, 1545]]))
#
#
# Predicted:  unacc Data:  (1, 2, 0, 1, 2, 0) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[  54,  382,   45, 1516,  607,  604, 1205,  101,  295]]))
#
#
# Predicted:  good Data:  (0, 1, 1, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 947,  722, 1143, 1246,  536,  760,  494,  312,  302]]))
#
#
# Predicted:  good Data:  (2, 3, 1, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1429,  411,  522,  868,  406,  690, 1387,  415, 1414]]))
#
#
# Predicted:  good Data:  (1, 2, 0, 1, 1, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1251,  746, 1504,  853,  687, 1019,  856,   36,  719]]))
#
#
# Predicted:  good Data:  (0, 1, 3, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1255, 1383, 1307, 1296,  936, 1363,  904,  364,  233]]))
#
#
# Predicted:  good Data:  (1, 0, 1, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 924,   15, 1206, 1540, 1058, 1135, 1347,  772, 1160]]))
#
#
# Predicted:  acc Data:  (1, 2, 2, 2, 2, 0) Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 178,  423,  614,  645,  810,  151,  322,  814, 1064]]))
#
#
# Predicted:  good Data:  (1, 0, 1, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1347,  883, 1004, 1357,  681,  788, 1135,  797,  318]]))
#
#
# Predicted:  unacc Data:  (1, 2, 1, 2, 1, 2) Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1038,  921, 1223, 1401,  853,  762,  687,  540,  711]]))
#
#
# Predicted:  good Data:  (2, 3, 0, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1139,  680,  522,  443,  415, 1414, 1531, 1430,   63]]))
#
#
# Predicted:  good Data:  (1, 1, 2, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  15,  463, 1104,  436,   21,  858,  976, 1160,  895]]))
#
#
# Predicted:  good Data:  (0, 0, 1, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1425,  331,  497, 1418,  846,  220,  235,  772,  722]]))
#
#
# Predicted:  good Data:  (0, 3, 3, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1293, 1108,  263,  561,  405, 1484,  663, 1016, 1009]]))
#
#
# Predicted:  unacc Data:  (2, 1, 2, 1, 2, 2) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 428, 1114, 1068, 1497,  915, 1051, 1507,  857, 1106]]))
#
#
# Predicted:  good Data:  (2, 3, 0, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 415, 1414, 1101,  601,  680,   85, 1271, 1090,  443]]))
#
#
# Predicted:  good Data:  (0, 2, 3, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 878,  561,  913,  314,  627,  733,  663, 1348,  410]]))
#
#
# Predicted:  good Data:  (0, 1, 1, 2, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1080,  842, 1136, 1203, 1154,    8,  594,  670,  797]]))
#
#
# Predicted:  unacc Data:  (3, 1, 3, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[  53, 1448,  660,   24, 1178, 1449,  698,  933,  748]]))
#
#
# Accuracy:  0.9364161849710982
